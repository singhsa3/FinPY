# %%
# 

import requests
import pandas as pd
import numpy as np

api_key = ''
data_type = input("Data type- time series or tech indicator: ")
def inputs():
  symbol = input('Enter ticker/forex/crypto/ETF/Index: ')
  interval = input('Interval- 1min, 5min, 15min, 30min, 45min, 1h, 2h, 4h, 8h, 1day, 1week, 1month: ')
  order = input('Order-asc, desc: ')
  start_date = input('Start Date(yyyy-mm-dd): ')
  end_date = input('End Date(yyyy-mm-dd): ')
  return symbol,interval,order,start_date,end_date

if data_type == 'time series':
  print('\nTicker eg.: AAPL, MSFT\nForex eg.: USD/JPY, USD/EUR\nCrypro eg.:BTC/USD, ETH/USD\nETF eg.:SPY, VTI\nIndex eg.:IXIC, SPX\n')
  inputs1 = inputs()
  api_url = f'https://api.twelvedata.com/time_series?symbol={inputs1[0]}&start_date={inputs1[3]}&end_date={inputs1[4]}&interval={inputs1[1]}&order={inputs1[2]}&apikey={api_key}'
elif data_type == 'tech indicator':
  tech_indi_json = requests.get('https://api.twelvedata.com/technical_indicators').json()
  print("\nList of Technical Indicators: "+str(np.array(pd.DataFrame(tech_indi_json['data']).columns))+"\n")
  tech_indi = input("Enter Tech Indicator exactly as mentioned above: ")
  print('\nTicker eg.: AAPL, MSFT, etc.\nForex eg.: USD/JPY, USD/EUR, etc.\nCrypro eg.:BTC/USD, ETH/USD, etc.\nETF eg.:SPY, VTI, etc.\nIndex eg.:IXIC, SPX, etc.\n')
  inputs1 = inputs()
  api_url = f'https://api.twelvedata.com/{tech_indi}?symbol={inputs1[0]}&start_date={inputs1[3]}&end_date={inputs1[4]}&interval={inputs1[1]}&include_ohlc=true&order={inputs1[2]}&apikey={api_key}'
else:
  print('Wrong Entry')
  
data = requests.get(api_url).json()
data_final = pd.DataFrame(data['values'])
data_final
# Out:
# Data type- time series or tech indicator: tech indicator
#
# List of Technical Indicators: ['acos' 'ad' 'add' 'adosc' 'adx' 'adxr' 'apo' 'aroon' 'aroonosc' 'asin'
#  'atan' 'atr' 'avg' 'avgprice' 'bbands' 'beta' 'bop' 'cci' 'ceil' 'cmo'
#  'coppock' 'correl' 'cos' 'cosh' 'crsi' 'dema' 'div' 'dpo' 'dx' 'ema'
#  'exp' 'floor' 'heikinashicandles' 'hlc3' 'ht_dcperiod' 'ht_dcphase'
#  'ht_phasor' 'ht_sine' 'ht_trendline' 'ht_trendmode' 'ichimoku' 'kama'
#  'keltner' 'kst' 'linearreg' 'linearregangle' 'linearregintercept'
#  'linearregslope' 'ln' 'log10' 'ma' 'macd' 'macdext' 'mama' 'mavp' 'max'
#  'maxindex' 'mcginley_dynamic' 'medprice' 'mfi' 'midpoint' 'midprice'
#  'min' 'minindex' 'minmax' 'minmaxindex' 'minus_di' 'minus_dm' 'mom'
#  'mult' 'natr' 'obv' 'percent_b' 'plus_di' 'plus_dm' 'ppo' 'roc' 'rocp'
#  'rocr' 'rocr100' 'rsi' 'rvol' 'sar' 'sarext' 'sin' 'sinh' 'sma' 'sqrt'
#  'stddev' 'stoch' 'stochf' 'stochrsi' 'sub' 'sum' 'supertrend'
#  'supertrend_heikinashicandles' 't3ma' 'tan' 'tanh' 'tema' 'trange'
#  'trima' 'tsf' 'typprice' 'ultosc' 'var' 'vwap' 'wclprice' 'willr' 'wma']
#
# Enter Tech Indicator exactly as mentioned above: ema
#
# Ticker eg.: AAPL, MSFT, etc.
# Forex eg.: USD/JPY, USD/EUR, etc.
# Crypro eg.:BTC/USD, ETH/USD, etc.
# ETF eg.:SPY, VTI, etc.
# Index eg.:IXIC, SPX, etc.
#
# Enter ticker/forex/crypto/ETF/Index: AAPL
# Interval- 1min, 5min, 15min, 30min, 45min, 1h, 2h, 4h, 8h, 1day, 1week, 1month: 45min
# Order-asc, desc: desc
# Start Date(yyyy-mm-dd): 2020-01-01
# End Date(yyyy-mm-dd): 2020-01-10
#                datetime       ema      open  ...       low     close   volume
# 0   2020-01-09 15:15:00  77.02537  77.26000  ...  77.14500  77.42750  3255804
# 1   2020-01-09 14:30:00  76.92484  77.23750  ...  77.06250  77.14250  2281828
# 2   2020-01-09 13:45:00  76.87043  77.27000  ...  77.18320  77.23490  1408709
# 3   2020-01-09 13:00:00  76.77931  76.90500  ...  76.85750  77.39450  3904436
# 4   2020-01-09 12:15:00  76.62551  76.98600  ...  76.55000  76.91602  3568809
# 5   2020-01-09 11:30:00  76.55288  77.44250  ...  77.23250  77.35750  3951859
# 6   2020-01-09 10:45:00  76.35173  77.27625  ...  77.24750  77.44250  3043103
# 7   2020-01-09 10:00:00  76.07903  77.07250  ...  76.85500  77.18375  4369653
# 8   2020-01-09 09:15:00  75.80286  76.80875  ...  76.71750  77.07500  8491157
# 9   2020-01-08 15:15:00  75.48482  76.02750  ...  75.56000  75.79750  4218755
# 10  2020-01-08 14:30:00  75.40665  75.66250  ...  75.63250  76.02500  3401101
# 11  2020-01-08 13:45:00  75.25206  75.65000  ...  75.63250  75.66125   914648
# 12  2020-01-08 13:00:00  75.14977  75.66125  ...  75.60000  75.65080  2773970
# 13  2020-01-08 12:15:00  75.02451  75.59953  ...  75.38250  75.65782  2839120
# 14  2020-01-08 11:30:00  74.86618  74.67050  ...  74.60250  75.59727  6310867
# 15  2020-01-08 10:45:00  74.68341  74.43250  ...  74.37500  74.74280  1685199
